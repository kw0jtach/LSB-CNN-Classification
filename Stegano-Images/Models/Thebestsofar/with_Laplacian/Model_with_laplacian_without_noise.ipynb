# %% [markdown]
# ## Necessary operations on the Dataset

# %%
import shutil
import os

base_path = 'stegoimagesdataset/test/test/'

folders_to_delete = ['stego_b64', 'stego_zip']

for folder in folders_to_delete:
    folder_path = os.path.join(base_path, folder)
    if os.path.exists(folder_path):
        shutil.rmtree(folder_path)
        print(f"Deleted folder : {folder_path}")
    else:
        print(f"Can't find the folder : {folder_path}")
# Out:
# Can't find the folder : stegoimagesdataset/test/test/stego_b64
# Can't find the folder : stegoimagesdataset/test/test/stego_zip

# %%
import os
from PIL import Image

def convert_clean_rgba_to_rgb(root_dirs):
    for root in root_dirs:
        clean_dir = os.path.join(root, 'clean')
        if not os.path.isdir(clean_dir):
            continue

        for fname in os.listdir(clean_dir):
            if not fname.lower().endswith('.png'):
                continue

            path = os.path.join(clean_dir, fname)
            try:
                with Image.open(path) as img:
                    if img.mode == 'RGBA':
                        rgb_img = img.convert('RGB')
                        rgb_img.save(path)
                        print(f"Converted RGBA → RGB: {path}")
            except Exception as e:
                print(f"Error processing {path}: {e}")

# Exemple d'utilisation :
train_dir = 'stegoimagesdataset/train/train'
val_dir   = 'stegoimagesdataset/val/val'
test_dir  = 'stegoimagesdataset/test/test'

convert_clean_rgba_to_rgb([train_dir, val_dir, test_dir])
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01985.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03175.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02649.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01167.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03158.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03894.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00668.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01236.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03586.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00807.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02584.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00736.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03666.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02959.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01408.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01412.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00776.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00436.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00266.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01286.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02565.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01705.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00192.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02905.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00160.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01134.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01175.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00981.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02140.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03152.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03843.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02183.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02130.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01400.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02908.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02272.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02624.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01477.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01522.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01512.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01976.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03576.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03549.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00214.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03800.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03799.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02749.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03684.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02478.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01869.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02371.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03685.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02199.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01314.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03675.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03419.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03113.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00675.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01027.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01982.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02525.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01595.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00120.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03578.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03334.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00692.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01486.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00182.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00777.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00764.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01665.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00742.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02595.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00706.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01841.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00105.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01508.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02150.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00343.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00691.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01497.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01771.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03425.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00558.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01557.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03447.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02920.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01466.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01562.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02065.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03989.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01858.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02787.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01154.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01253.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02848.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03544.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01433.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03174.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01112.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03760.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01722.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02384.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03269.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03881.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00256.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02184.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01733.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01768.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01762.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02771.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02793.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03115.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01917.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00365.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00610.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01805.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02169.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03249.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00017.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02654.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03517.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03124.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03939.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00763.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03490.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01310.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01599.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03927.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02817.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03389.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02961.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00402.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03166.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00958.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02741.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00397.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02393.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00302.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03724.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00369.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03999.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01240.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03353.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01136.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00935.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00049.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00639.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00161.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02803.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02315.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02885.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02931.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00254.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00632.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02023.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03399.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03046.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01268.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03806.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00050.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03265.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01774.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03160.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01987.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00489.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02757.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02831.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02530.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03957.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01652.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00279.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00423.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03758.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03801.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03469.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03889.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03589.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02057.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03914.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00834.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02468.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02876.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03213.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02978.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00067.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03698.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03690.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01416.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01117.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01315.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00440.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03949.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00290.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02390.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01339.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00347.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00046.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03131.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00545.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01149.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02948.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02361.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03805.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/03562.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00171.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01721.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01949.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00564.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01321.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02001.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01850.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02019.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00500.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02727.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/00803.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02780.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/02275.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/01092.png
# Converted RGBA → RGB: stegoimagesdataset/train/train/clean/
png
# Converted RGBA → RGB: stegoimagesdataset/test/test/clean/05365.png
# Converted RGBA → RGB: stegoimagesdataset/test/test/clean/04490.png

# %% [markdown]
# """
# ## `CustomTrainAugmentation` Class
#
# This class defines custom data augmentations for training images, which help improve the robustness of a model by introducing variations in the input data. These augmentations are applied during training to simulate real-world noise and transformations.
#
# #### Noise Addition Methods:
# - **`add_gaussian_noise`:** Adds random Gaussian noise to the image by generating noise with a specified mean and standard deviation.
# - **`add_salt_pepper`:** Adds salt-and-pepper noise by randomly selecting pixels to turn either white (salt) or black (pepper).

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image, ImageFilter
import numpy as np
import random
import re
import cv2
from torchvision import transforms

class CustomTrainAugmentation:
    def __init__(self):
        # Define the base transformations applied to every image
        self.base_transform = transforms.Compose([
            # Randomly flip the image horizontally with a 50% chance
            transforms.RandomHorizontalFlip(p=0.5),

            # These are optional transformations that are currently commented out
            # transforms.RandomRotation(degrees=5),  # Randomly rotate the image by up to 5 degrees
        ])


    def __call__(self, img):
        # Apply the base transformations (e.g., flipping)
        img = self.base_transform(img)

        # Generate a random number to decide which noise effect to apply
        r = random.random()
        if r < 0.2:
            # 20% chance to apply Gaussian noise
            img = self.add_gaussian_noise(img)
        elif r < 0.4:
            # 20% chance to apply salt-and-pepper noise
            img = self.add_salt_pepper(img)
        elif r < 0.6:
            # 20% chance to apply Gaussian blur
            img = img.filter(ImageFilter.GaussianBlur(radius=1))

        # Return the final augmented image
        return img  # self.normalize(img)

    def add_gaussian_noise(self, img):
        # Convert the image to a NumPy array and normalize to [0, 1]
        np_img = np.array(img).astype(np.float32) / 255.0

        # Generate Gaussian noise with mean=0 and std=0.02
        noise = np.random.normal(0, 0.02, np_img.shape)

        # Add noise and clip the result to stay within valid range
        noisy = np.clip(np_img + noise, 0, 1)

        # Convert back to PIL image in [0, 255] range
        return Image.fromarray((noisy * 255).astype(np.uint8))

    def add_salt_pepper(self, img, amount=0.01):
        # Convert image to NumPy array
        np_img = np.array(img)
        h, w, c = np_img.shape

        # Calculate number of salt (white) pixels
        num_salt = int(amount * h * w)
        coords = [np.random.randint(0, i - 1, num_salt) for i in (h, w)]
        np_img[coords[0], coords[1], :] = 255  # Set selected pixels to white

        # Calculate number of pepper (black) pixels
        num_pepper = int(amount * h * w)
        coords = [np.random.randint(0, i - 1, num_pepper) for i in (h, w)]
        np_img[coords[0], coords[1], :] = 0  # Set selected pixels to black

        # Convert back to PIL image
        return Image.fromarray(np_img)

# %% [markdown]
# ## `BalancedStegoDatasetGPU` Class
#
# This class is designed for creating a balanced dataset containing both clean and stego images. It includes preprocessing and transformation steps, with the flexibility to apply additional filters like the Laplacian.

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import random
import re
import cv2
import numpy as np

class BalancedStegoDatasetGPU(Dataset):
    def __init__(self, clean_dir, stego_dir, transform=None, device='cuda', apply_laplacian=False):
        self.device = device  # Device to store tensors (usually 'cuda' for GPU)
        self.transform = transform  # transform (e.g., augmentations)
        self.apply_laplacian = apply_laplacian  # Whether to apply Laplacian filter to images

        # Default normalization and resizing pipeline
        self.normalize = transforms.Compose([
            transforms.Resize((256, 256)),  # Resize image to 256x256
            transforms.ToTensor(),  # Convert to PyTorch tensor
            transforms.Normalize(mean=[0.485, 0.456, 0.406],  # Standard ImageNet mean
                                 std=[0.229, 0.224, 0.225])   # Standard ImageNet std
        ])

        self.images = []  # List of image tensors
        self.labels = []  # Corresponding labels: 0 for clean, 1 for stego

        # Get and sort all PNG files from the clean directory
        clean_imgs = sorted([f for f in os.listdir(clean_dir) if f.endswith('.png')])

        for clean_img in clean_imgs:
            clean_path = os.path.join(clean_dir, clean_img)
            base_id = os.path.splitext(clean_img)[0]  # Remove extension

            # Load clean image, apply preprocessing, and store on device
            img_clean = Image.open(clean_path).convert("RGB")
            img_clean = self.preprocess(img_clean)
            self.images.append(img_clean.to(self.device))
            self.labels.append(torch.tensor(0, dtype=torch.long, device=self.device))  # Label 0 = clean

            # Use regex to find matching stego image(s) with similar base name
            pattern = f"image_{base_id}_.+\\.png"
            stego_matches = [f for f in os.listdir(stego_dir) if re.match(pattern, f)]

            if stego_matches:
                # Randomly choose one stego image if multiple are found
                stego_img = random.choice(stego_matches)
                stego_path = os.path.join(stego_dir, stego_img)

                # Load stego image, preprocess, and store on device
                img_stego = Image.open(stego_path).convert("RGB")
                img_stego = self.preprocess(img_stego)
                self.images.append(img_stego.to(self.device))
                self.labels.append(torch.tensor(1, dtype=torch.long, device=self.device))  # Label 1 = stego

        # Stack all image and label tensors into single batched tensors
        self.images = torch.stack(self.images)
        self.labels = torch.stack(self.labels)

    def preprocess(self, img_pil):
        # Apply optional user-defined transforms first (e.g., augmentations)
        img_pil = self.transform(img_pil)

        # Convert PIL image to NumPy array for Laplacian processing
        img_np = np.array(img_pil)

        if self.apply_laplacian:
            # Apply Laplacian filter to each channel (edge enhancement)
            laplacian_channels = []
            for c in range(3):  # RGB channels
                channel = img_np[:, :, c]
                laplacian = cv2.Laplacian(channel, cv2.CV_32F, ksize=3)
                laplacian = cv2.convertScaleAbs(laplacian)  # Convert to 8-bit image
                laplacian_channels.append(laplacian)

            # Merge channels back into a 3-channel image
            img_np = np.stack(laplacian_channels, axis=-1)

        # Convert back to PIL image and apply normalization
        img_pil = Image.fromarray(img_np)
        return self.normalize(img_pil)

    def __getitem__(self, index):
        # Return (image, label) pair at the given index
        return self.images[index], self.labels[index]

    def __len__(self):
        # Return the total number of samples
        return len(self.labels)

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
from PIL import Image
import os

train_transform = CustomTrainAugmentation()

standard_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5)  # 50% chance of flipping the image horizontally
])

# training dataset using the custom augmentation and Laplacian filtering
train_dataset = BalancedStegoDatasetGPU(
    clean_dir='stegoimagesdataset/train/train/clean',  # Path to clean training images
    stego_dir='stegoimagesdataset/train/train/stego',  # Path to stego training images
    transform=standard_transform,#train_transform,  # Apply custom data augmentation
    device='cuda',  # Move all tensors to GPU
    apply_laplacian=True  # Apply Laplacian filter (edge enhancement)
)

# validation dataset using standard transformation and Laplacian filtering
val_dataset = BalancedStegoDatasetGPU(
    clean_dir='stegoimagesdataset/val/val/clean',  # Path to clean validation images
    stego_dir='stegoimagesdataset/val/val/stego',  # Path to stego validation images
    transform=standard_transform,  # Apply basic augmentation
    device='cuda',
    apply_laplacian=True
)

# batch size for loaders
batch_size = 32

# DataLoader for training data with shuffling enabled
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# DataLoader for validation data without shuffling
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
from collections import Counter

labels_train = [int(label) for _, label in train_dataset]
labels_val = [int(label) for _, label in val_dataset]
print(Counter(labels_train))
print(Counter(labels_val))

for input, labels in train_loader:
  print(input.size())
  print(labels.size())
  break
# Out:
# Counter({0: 4000, 1: 4000})
# Counter({0: 2000, 1: 2000})
# torch.Size([32, 3, 256, 256])
# torch.Size([32])

# %%
import torch
import torch.nn as nn
import torchvision.models as models

# Load a pretrained ResNet-18 model with default weights
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

in_features = model.fc.in_features  # ResNet18's last layer has input features (usually 512)

# Replace the original fc layer with a new one for binary classification (2 classes)
model.fc = nn.Sequential(
    nn.Dropout(p=0.5),  # dropout for regularization (reduces overfitting)
    nn.Linear(in_features, 2)  # New linear layer with 2 output units: [clean, stego]
)

# device: GPU if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Move the entire model to the selected device
model = model.to(device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Training Function with Early Stopping and LR Scheduler
# The function below defines a complete training loop for a PyTorch model.
# It includes key features such as:
#
# - Training and validation steps per epoch
#
# - Accuracy and loss tracking
#
# - ReduceLROnPlateau scheduler: automatically lowers the learning rate when the validation loss plateaus
#
# - Early stopping: stops training if no improvement is observed after a certain number of epochs
#
# - Model checkpointing: saves the model with the best validation performance to disk

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import time

from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import time
import matplotlib.pyplot as plt


def train(model, train_loader, val_loader, criterion, optimizer, num_epochs=100, patience=10, save_path="best_model.pth"):
    best_val_loss = float('inf')
    epochs_no_improve = 0
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    print(f"Starting training for model: {model.__class__.__name__} at {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())} for {num_epochs} epochs")

    for epoch in range(1, num_epochs + 1):
        model.train()
        running_loss = 0.0
        correct = total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        train_loss = running_loss / total
        train_acc = 100 * correct / total

        model.eval()
        val_loss = 0.0
        val_correct = val_total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                preds = outputs.argmax(dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_loss = val_loss / val_total
        val_acc = 100 * val_correct / val_total

        scheduler.step(val_loss)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_acc)
        val_accuracies.append(val_acc)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
            improve_str = "New Best Model found!"
        else:
            epochs_no_improve += 1
            improve_str = f"No improvement ({epochs_no_improve}/{patience})"

        print(
            f"Epoch {epoch:>3}/{num_epochs}  "
            f"| Train Loss: {train_loss:.4f}, Train Acc: {train_acc:5.2f}%  "
            f"| Val Loss: {val_loss:.4f}, Val Acc: {val_acc:5.2f}%  "
            f"{improve_str}"
        )

        if epochs_no_improve >= patience:
            print(f"Early stopping triggered after {epoch} epochs (val_loss didn't drop).")
            break

    print(f"Training complete. Best Validation Loss: {best_val_loss:.4f}")

    epochs_range = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_losses, label='Train Loss')
    plt.plot(epochs_range, val_losses, label='Val Loss')
    plt.title("Loss over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, train_accuracies, label='Train Acc')
    plt.plot(epochs_range, val_accuracies, label='Val Acc')
    plt.title("Accuracy over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    plt.tight_layout()
    plt.show()

    return model

# %% [markdown]
# ## Loss Function, Optimizer, and Training Launch
# In this cell, we define the loss function and the optimizer, then launch the training process:
#
# - CrossEntropyLoss is used, which is the standard choice for multi-class classification problems.
#
# - The Adam optimizer is initialized with a learning rate of 1e-4 and a small weight decay (1e-4) for regularization.
#
# The training loop is started using the previously defined train function, with:
#
# - 100 maximum epochs
#
# - 15 patience epochs for early stopping (training stops early if validation loss doesn't improve)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss() # Cross entropy loss for multi-class classification
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4) # Adam optimizer

trained_model = train(model, train_loader, val_loader, criterion, optimizer, 100, 15)
# Out:
# Starting training for model: ResNet at 2025-05-03 09:08:35 for 100 epochs
# Epoch   1/100  | Train Loss: 0.2642, Train Acc: 86.99%  | Val Loss: 0.0246, Val Acc: 99.22%  New Best Model found!
# Epoch   2/100  | Train Loss: 0.0214, Train Acc: 99.30%  | Val Loss: 0.9214, Val Acc: 79.42%  No improvement (1/15)
# Epoch   3/100  | Train Loss: 0.0175, Train Acc: 99.36%  | Val Loss: 0.0017, Val Acc: 100.00%  New Best Model found!
# Epoch   4/100  | Train Loss: 0.0105, Train Acc: 99.64%  | Val Loss: 0.0007, Val Acc: 100.00%  New Best Model found!
# Epoch   5/100  | Train Loss: 0.0179, Train Acc: 99.40%  | Val Loss: 0.0174, Val Acc: 99.40%  No improvement (1/15)
# Epoch   6/100  | Train Loss: 0.0090, Train Acc: 99.62%  | Val Loss: 0.0002, Val Acc: 100.00%  New Best Model found!
# Epoch   7/100  | Train Loss: 0.0118, Train Acc: 99.60%  | Val Loss: 0.8939, Val Acc: 53.17%  No improvement (1/15)
# Epoch   8/100  | Train Loss: 0.0286, Train Acc: 98.88%  | Val Loss: 0.0131, Val Acc: 99.97%  No improvement (2/15)
# Epoch   9/100  | Train Loss: 0.0084, Train Acc: 99.65%  | Val Loss: 0.0006, Val Acc: 100.00%  No improvement (3/15)
# Epoch  10/100  | Train Loss: 0.0052, Train Acc: 99.80%  | Val Loss: 0.0004, Val Acc: 100.00%  No improvement (4/15)
# Epoch  11/100  | Train Loss: 0.0050, Train Acc: 99.79%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (5/15)
# Epoch  12/100  | Train Loss: 0.0075, Train Acc: 99.58%  | Val Loss: 0.0600, Val Acc: 97.45%  No improvement (6/15)
# Epoch  13/100  | Train Loss: 0.0062, Train Acc: 99.75%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (7/15)
# Epoch  14/100  | Train Loss: 0.0028, Train Acc: 99.88%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (8/15)
# Epoch  15/100  | Train Loss: 0.0052, Train Acc: 99.78%  | Val Loss: 0.0002, Val Acc: 100.00%  New Best Model found!
# Epoch  16/100  | Train Loss: 0.0039, Train Acc: 99.81%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (1/15)
# Epoch  17/100  | Train Loss: 0.0024, Train Acc: 99.86%  | Val Loss: 0.0002, Val Acc: 100.00%  No improvement (2/15)
# Epoch  18/100  | Train Loss: 0.0024, Train Acc: 99.90%  | Val Loss: 0.0002, Val Acc: 100.00%  New Best Model found!
# Epoch  19/100  | Train Loss: 0.0021, Train Acc: 99.90%  | Val Loss: 0.0004, Val Acc: 100.00%  No improvement (1/15)
# Epoch  20/100  | Train Loss: 0.0021, Train Acc: 99.89%  | Val Loss: 0.0430, Val Acc: 97.95%  No improvement (2/15)
# Epoch  21/100  | Train Loss: 0.0016, Train Acc: 99.90%  | Val Loss: 0.0001, Val Acc: 100.00%  New Best Model found!
# Epoch  22/100  | Train Loss: 0.0013, Train Acc: 99.90%  | Val Loss: 0.0001, Val Acc: 100.00%  New Best Model found!
# Epoch  23/100  | Train Loss: 0.0011, Train Acc: 99.95%  | Val Loss: 0.0001, Val Acc: 100.00%  New Best Model found!
# Epoch  24/100  | Train Loss: 0.0011, Train Acc: 99.94%  | Val Loss: 0.0001, Val Acc: 100.00%  No improvement (1/15)
# Epoch  25/100  | Train Loss: 0.0011, Train Acc: 99.94%  | Val Loss: 0.0000, Val Acc: 100.00%  New Best Model found!
# Epoch  26/100  | Train Loss: 0.0009, Train Acc: 99.95%  | Val Loss: 0.0001, Val Acc: 100.00%  No improvement (1/15)
# Epoch  27/100  | Train Loss: 0.0121, Train Acc: 99.58%  | Val Loss: 0.0025, Val Acc: 99.95%  No improvement (2/15)
# Epoch  28/100  | Train Loss: 0.0043, Train Acc: 99.85%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (3/15)
# Epoch  29/100  | Train Loss: 0.0022, Train Acc: 99.90%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (4/15)
# Epoch  30/100  | Train Loss: 0.0016, Train Acc: 99.91%  | Val Loss: 0.0001, Val Acc: 100.00%  No improvement (5/15)
# Epoch  31/100  | Train Loss: 0.0027, Train Acc: 99.89%  | Val Loss: 0.0004, Val Acc: 99.97%  No improvement (6/15)
# Epoch  32/100  | Train Loss: 0.0018, Train Acc: 99.92%  | Val Loss: 0.0002, Val Acc: 100.00%  No improvement (7/15)
# Epoch  33/100  | Train Loss: 0.0009, Train Acc: 99.96%  | Val Loss: 0.0001, Val Acc: 100.00%  No improvement (8/15)
# Epoch  34/100  | Train Loss: 0.0021, Train Acc: 99.92%  | Val Loss: 0.0003, Val Acc: 100.00%  No improvement (9/15)
# Epoch  35/100  | Train Loss: 0.0012, Train Acc: 99.95%  | Val Loss: 0.0001, Val Acc: 100.00%  No improvement (10/15)
# Epoch  36/100  | Train Loss: 0.0026, Train Acc: 99.91%  | Val Loss: 0.0003, Val Acc: 99.97%  No improvement (11/15)
# Epoch  37/100  | Train Loss: 0.0017, Train Acc: 99.95%  | Val Loss: 0.0014, Val Acc: 99.97%  No improvement (12/15)
# Epoch  38/100  | Train Loss: 0.0009, Train Acc: 99.96%  | Val Loss: 0.0012, Val Acc: 99.97%  No improvement (13/15)
# Epoch  39/100  | Train Loss: 0.0008, Train Acc: 99.96%  | Val Loss: 0.0013, Val Acc: 99.97%  No improvement (14/15)
# Epoch  40/100  | Train Loss: 0.0008, Train Acc: 99.96%  | Val Loss: 0.0006, Val Acc: 99.97%  No improvement (15/15)
# Early stopping triggered after 40 epochs (val_loss didn't drop).
# Training complete. Best Validation Loss: 0.0000

# %% [markdown]
# ## Test Set Preparation (Standard and Robust)
# This cell prepares two separate test datasets and their DataLoaders:
#
# - Standard Test Set: Uses minimal augmentation (random horizontal flip only) and is meant to evaluate the model in normal, clean test conditions.
#
# - Robust Test Set: Uses the same images but applies more aggressive augmentations like noise and blur (via CustomTrainAugmentation) to simulate challenging or perturbed inputs.
#
# Both datasets use Laplacian filtering to emphasize edges and details, which may help the model detect subtle steganographic artifacts.
#
# By comparing performance on both sets, we can assess not only accuracy, but also the robustness of the trained model.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
from PIL import Image
import os

standard_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5)
])
test_dataset = BalancedStegoDatasetGPU(
    clean_dir='stegoimagesdataset/test/test/clean',
    stego_dir='stegoimagesdataset/test/test/stego',
    transform=standard_transform,
    device='cuda',
    apply_laplacian=True
)
batch_size = 32
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

robust_test_transform = CustomTrainAugmentation()

robust_test_dataset = test_dataset = BalancedStegoDatasetGPU(
    clean_dir='stegoimagesdataset/test/test/clean',
    stego_dir='stegoimagesdataset/test/test/stego',
    transform=robust_test_transform,
    device='cuda',
    apply_laplacian=True
)

robust_test_loader = DataLoader(robust_test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import torch


# Function to evaluate the model on a given DataLoader
def test_model(model, loader, device):
    model.eval()
    model.to(device)

    all_preds = []
    all_labels = []
    all_images = []

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            all_images.append(images.cpu())

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)
    all_images = torch.cat(all_images)

    return all_images, all_preds, all_labels

# Function to print a classification report (precision, recall, f1-score)
def generate_classification_report(labels, preds, classes):
    report = classification_report(labels, preds, target_names=classes)
    print("\n=== 📊 Rapport de classification ===\n")
    print(report)

# Function to display a confusion matrix
def plot_confusion_matrix(model, dataloader):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(cm, display_labels=['Clean', 'Stego'])
    disp.plot(cmap='Blues', values_format='d')
    plt.title("Confusion Matrix")
    plt.show()

# %%
model.load_state_dict(torch.load('best_model.pth'))  # Load the best model saved during training

# Evaluate the model on the standard test dataset
images, preds, labels = test_model(model, test_loader, device)

classes = ['clean', 'stego']  # These are the two classes in the classification task

generate_classification_report(labels, preds, classes)

# Plot the confusion matrix for the standard test set
plot_confusion_matrix(model, test_loader)

# Evaluate the model on the robust test dataset (with stronger augmentations)
images_robust, preds_robust, labels_robust = test_model(model, robust_test_loader, device)

generate_classification_report(labels_robust, preds_robust, classes)

plot_confusion_matrix(model, robust_test_loader)
# Out:
# === 📊 Rapport de classification ===
#
#               precision    recall  f1-score   support
#
#        clean       1.00      1.00      1.00      2000
#        stego       1.00      1.00      1.00      2000
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
# === 📊 Rapport de classification ===
#
#               precision    recall  f1-score   support
#
#        clean       0.80      0.79      0.80      2000
#        stego       0.79      0.80      0.80      2000
#
#     accuracy                           0.80      4000
#    macro avg       0.80      0.80      0.80      4000
# weighted avg       0.80      0.80      0.80      4000
